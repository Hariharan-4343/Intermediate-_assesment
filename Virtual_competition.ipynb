# %% [markdown]
# Consider the following Python dictionary `data` and Python list `labels`:
#
# ``` python
# data = {'animal': ['cat', 'cat', 'snake', 'dog', 'dog', 'cat', 'snake', 'cat', 'dog', 'dog'],
#         'age': [2.5, 3, 0.5, np.nan, 5, 2, 4.5, np.nan, 7, 3],
#         'visits': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
#         'priority': ['yes', 'yes', 'no', 'yes', 'no', 'no', 'no', 'yes', 'no', 'no']}
#
# labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
# ```
#
# **1.** Create a DataFrame `df` from this dictionary `data` which has the index `labels`.

# %%
data = pd.DataFrame(['data'])
print(data.head())
# Out:
#       0
# 0  data

# %% [markdown]
# **2.** Display a summary of the basic information about this DataFrame and its data (*hint: there is a single method that can be called on the DataFrame*).

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       1 non-null      object
# dtypes: object(1)
# memory usage: 136.0+ bytes

# %% [markdown]
# **3.** Return the first 3 rows of the DataFrame `df`.

# %%
data = data.head(3)
print(data)
# Out:
#       0
# 0  data

# %% [markdown]
# **4.** Display the 'animal' and 'age' columns from the DataFrame `df`

# %%
riginal_data = pd.DataFrame({'animal': ['cat', 'dog', 'bird'], 'age': [2, 5, 1]})

# %% [markdown]
# **5.** Display the data in rows `[3, 4, 8]` *and* in columns `['animal', 'age']'

# %%
original_data = pd.DataFrame({'animal': ['cat', 'dog', 'bird'], 'age': [2, 5, 1]})
print(original_data.loc[original_data.index[[0, 1, 2]], ['animal', 'age']])
# Out:
#   animal  age
# 0    cat    2
# 1    dog    5
# 2   bird    1

# %%
print(data.loc[data.index[[3, 4, 8]], ['animal', 'age']])

# %% [markdown]
# **6.** Select only the rows where the number of visits is greater than 3.

# %%
print(original_data[original_data['age'] > 1])
# Out:
#   animal  age
# 0    cat    2
# 1    dog    5

# %% [markdown]
# **7.** Select the rows where the age is missing, i.e. it is `NaN`.

# %%
data = original_data.copy()

print(data[data['age'].isnull()])
# Out:
# Empty DataFrame
# Columns: [animal, age]
# Index: []

# %% [markdown]
# **8.** Select the rows where the animal is a cat *and* the age is less than 3.

# %%
print(data[(data['animal'] == 'cat') & (data['age'] < 3)])
# Out:
#   animal  age
# 0    cat    2

# %% [markdown]
# **9.** Select the rows where the age is between 2 and 4 (inclusive)

# %%
print(data[data['age'].between(2, 4)])
# Out:
#   animal  age
# 0    cat    2

# %% [markdown]
# **10.** Change the age in row 'f' to 1.5.

# %%
data.at['f', 'age'] = 1.5
print(data)
# Out:
#   animal  age
# 0    cat  2.0
# 1    dog  5.0
# 2   bird  1.0
# f    NaN  1.5

# %% [markdown]
# **11.** Calculate the sum of all visits in `df` (i.e. the total number of visits).

# %%
data['visits'] = [1, 2, 3, 4] # Example values, replace with your actual data
print(data['visits'].sum())
# Out:
# 10

# %% [markdown]
# **12.** Calculate the mean age for each different animal in `df`.

# %%
print(data.groupby('animal')['age'].mean())
# Out:
# animal
# bird    1.0
# cat     2.0
# dog     5.0
# Name: age, dtype: float64

# %% [markdown]
# **13.** Append a new row 'k' to `df` with your choice of values for each column. Then delete that row to return the original DataFrame.

# %%
data.loc['k'] = ['snake', 2.5, 2] # Removed 'yes' to match the number of columns
print(data)
data = data.drop('k')
# Out:
#   animal  age  visits
# 0    cat  2.0       1
# 1    dog  5.0       2
# 2   bird  1.0       3
# f    NaN  1.5       4
# k  snake  2.5       2

# %% [markdown]
# **14.** Count the number of each type of animal in `df`.

# %%
print(data['animal'].value_counts())
# Out:
# animal
# cat     1
# dog     1
# bird    1
# Name: count, dtype: int64

# %% [markdown]
# **15.** Sort `df` first by the values in the 'age' in *decending* order, then by the value in the 'visits' column in *ascending* order (so row `i` should be first, and row `d` should be last).

# %%
print(data.sort_values(by=['age', 'visits'], ascending=[False, True]))
# Out:
#   animal  age  visits
# 1    dog  5.0       2
# 0    cat  2.0       1
# f    NaN  1.5       4
# 2   bird  1.0       3

# %% [markdown]
# **16.** The 'priority' column contains the values 'yes' and 'no'. Replace this column with a column of boolean values: 'yes' should be `True` and 'no' should be `False`.

# %%
if 'priority' in data.columns:
    data['priority'] = data['priority'].map({'yes': True, 'no': False})
    print(data)
else:
    print("Column 'priority' not found in the DataFrame.")
# Out:
# Column 'priority' not found in the DataFrame.

# %% [markdown]
# **17.** In the 'animal' column, change the 'snake' entries to 'python'.

# %%
data = {'animal': ['cat', 'dog', 'snake', 'bird']}
df = pd.DataFrame(data)

df['animal'] = df['animal'].replace('snake', 'python')
print(df)
# Out:
#    animal
# 0     cat
# 1     dog
# 2  python
# 3    bird

# %% [markdown]
# **18.** Load the ny-flights dataset to Python

# %%
df_flights = pd.read_csv('/content/ny-flights.csv')
print(df_flights.head())
# Out:
#                fl_date unique_carrier  airline_id tail_num  fl_num origin  \
# 0  2014-01-01 00:00:00             AA       19805   N338AA       1    JFK
# 1  2014-01-01 00:00:00             AA       19805   N335AA       3    JFK
# 2  2014-01-01 00:00:00             AA       19805   N327AA      21    JFK
# 3  2014-01-01 00:00:00             AA       19805   N3EHAA      29    LGA
# 4  2014-01-01 00:00:00             AA       19805   N319AA     117    JFK
#
#   dest  dep_time  dep_delay  arr_time  arr_delay  cancelled  \
# 0  LAX     914.0       14.0    1238.0       13.0        0.0
# 1  LAX    1157.0       -3.0    1523.0       13.0        0.0
# 2  LAX    1902.0        2.0    2224.0        9.0        0.0
# 3  PBI     722.0       -8.0    1014.0      -26.0        0.0
# 4  LAX    1347.0        2.0    1706.0        1.0        0.0
#
#                    arr                  dep
# 0  2014-01-01 12:38:00  2014-01-01 09:14:00
# 1  2014-01-01 15:23:00  2014-01-01 11:57:00
# ...

# %%
max_airline_id = df_flights['airline_id'].value_counts().idxmax()
print(f"The airline ID present maximum times is: {max_airline_id}")
# Out:
# The airline ID present maximum times is: 20409

# %% [markdown]
# **20.** Draw a plot between dep_delay and arr_delay

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
plt.scatter(df_flights['dep_delay'], df_flights['arr_delay'], alpha=0.5, color='b')
plt.title('Departure Delay vs Arrival Delay')
plt.xlabel('Departure Delay (minutes)')
plt.ylabel('Arrival Delay (minutes)')
plt.grid(True)
plt.show()

# %%
df1 = pd.read_csv('/diabetes_model.csv')
print(df1.head())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            5       77             82             41       42  35.8
# 1            9      122             56              0        0  33.3
# 2            0      113             76              0        0  33.3
# 3            1      139             62             41      480  40.7
# 4           10      161             68             23      132  25.5
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.156   35        0
# 1                     1.114   33        1
# 2                     0.278   23        1
# 3                     0.536   21        0
# 4                     0.326   47        1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1.head()
df1.info()
df1.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               614 non-null    int64
#  1   Glucose                   614 non-null    int64
#  2   BloodPressure             614 non-null    int64
#  3   SkinThickness             614 non-null    int64
#  4   Insulin                   614 non-null    int64
#  5   BMI                       614 non-null    float64
#  6   DiabetesPedigreeFunction  614 non-null    float64
#  7   Age                       614 non-null    int64
#  8   Outcome                   614 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 43.3 KB
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   614.000000  614.000000     614.000000     614.000000  614.000000
# ...

# %%
df1.hist(figsize=(10, 8))
plt.tight_layout()
plt.show()

# %%
df1.plot(kind='box', subplots=True, layout=(4,4), sharex=False, sharey=False, figsize=(12, 10))
plt.tight_layout()
plt.show()

# %%
df1.plot(kind='density', subplots=True, layout=(4,4), sharex=False, sharey=False, figsize=(12, 10))
plt.tight_layout()
plt.show()

# %%
sns.pairplot(df1)
plt.show()

# %%
sns.pairplot(df1)
plt.show()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df1.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(df1, figsize=(12, 10))
plt.show()

# %%
categorical_columns = df1.select_dtypes(include=['object']).columns
for column in categorical_columns:
    plt.figure(figsize=(10, 6))
    sns.countplot(y=column, data=df1)

    plt.show()

# %%
plt.subplot(3, 3, 1)
plt.hist(df1['Age'], bins=10, edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Age')
# Out:
# Text(0.5, 1.0, 'Histogram of Age')

# %%
plt.subplot(3, 3, 2)
sns.boxplot(x='Glucose', data=df1)
plt.xlabel('Glucose')
plt.title('Boxplot of Glucose')
# Out:
# Text(0.5, 1.0, 'Boxplot of Glucose')

# %%
plt.subplot(3, 3, 3)
plt.hist(df1['BMI'], bins=10, edgecolor='black')
plt.xlabel('BMI')
plt.title('Histogram of BMI')
# Out:
# Text(0.5, 1.0, 'Histogram of BMI')

# %%
plt.subplot(3, 3, 4)
sns.pairplot(df1[['Glucose', 'BloodPressure', 'BMI', 'Insulin', 'Outcome']], hue='Outcome')
plt.title('Pairplot of Glucose, BloodPressure, BMI, Insulin by Outcome')
# Out:
# Text(0.5, 1.0, 'Pairplot of Glucose, BloodPressure, BMI, Insulin by Outcome')

# %%
plt.subplot(3, 3, 5)
sns.heatmap(df1.corr(), annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')

plt.tight_layout()
plt.show()
